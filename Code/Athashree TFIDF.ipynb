# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


import warnings
import pandas as pd
import numpy as np
import random
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from pandas.core.common import SettingWithCopyWarning
from pathlib import Path
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/anthony/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
data = pd.read_csv('Downloads/MFTD_en_exploded.csv')

# %%
def clean_text(data, old_field, clean_field):
    #convert to lowercase
    data[clean_field] = data[old_field].str.lower()
    #remove punctuation, numbers and special characters
    data[clean_field] = data[clean_field].str.replace("[^a-zA-Z#]", " ")
    #remove short words (eg: I've -> i ve --> removing such words with length<3)
    data[clean_field] = data[clean_field].apply(lambda elem: re.sub(r"\b\w{1,2}\b", "", elem))
    return data


# In[9]:


data = clean_text(data,'content', 'clean_stories')
# Out:
# <ipython-input-8-0281e3e29130>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data[clean_field] = data[clean_field].str.replace("[^a-zA-Z#]", " ")

# %%
# ### Variation 1: Use Tokenization, Lemmatization and TFIDF (This will take longer as we are tokenizing for lemmatization and joining the words again for TFIDF)

# ## Tokenization

# In[11]:


def tokenzie_words(data,field_name,new_field_name):
    data[new_field_name] = data[field_name].apply(lambda x: word_tokenize(x))
    return data


# In[12]:


data = tokenzie_words(data, 'clean_stories','type1_data')


# ## Lemmatization

# In[13]:


def word_lemmatizer(text):
    lem_text = [WordNetLemmatizer().lemmatize(i) for i in text]
    return lem_text


# In[14]:


data['type1_data'] = data['type1_data'].apply(lambda x: word_lemmatizer(x))
data['type1_data'] = [' '.join(map(str, l)) for l in data['type1_data']]


# ### Variation 2: Not using Tokenization and Lemmatization

# In[16]:


data['type2_data'] = data['clean_stories']


def tfidf(data,field_name):
    tfIdfVectorizer=TfidfVectorizer(use_idf=True,stop_words="english",lowercase=True)
    tfIdf = tfIdfVectorizer.fit_transform(data[field_name])
    for ind in data.index:
        df = pd.DataFrame(tfIdf[ind].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF"])
        df = df[df['TF-IDF'] != 0]
        df = df.sort_values('TF-IDF',ascending=False)
        df = df['TF-IDF'].to_dict()
        data.at[ind,field_name] = df



tfidf(data,'type1_data')


tfidf(data,'type2_data')


data.to_pickle("Downloads/folktales-tfidf.pkl")

# %%
data
# Out:
#      Unnamed: 0            name  \
# 0            16  trans-1017.xml
# 1            23  trans-1026.xml
# 2            28  trans-1036.xml
# 3            30   trans-104.xml
# 4            34  trans-1045.xml
# ..          ...             ...
# 411        2536  trans-9938.xml
# 412        2537  trans-9939.xml
# 413        2538  trans-9941.xml
# 414        2540   trans-998.xml
# 415        2540   trans-998.xml
#
#                                                content  \
# 0    \nHill and vale do not come together, but the ...
# 1    \nThere was once a countryman who had money an...
# 2    \nThere was once a mother who had a little boy...
# 3    And the sister wept over her poor lost brother...
# 4    \nThere was once a rich man, who had a servant...
# ..                                                 ...
# 411  \nOnce upon a time, a purdy little mouse sat i...
# 412  \n(Valencian version) \nLong, long ago, there ...
# 413  \nONCE in summer-time the bear and the wolf we...
# 414  \nThere was once a little child whose mother g...
# 415  \nThere was once a little child whose mother g...
#
#       Translated_from.Author Translated_from.Book Title  \
# 0      Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 1      Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 2      Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 3      Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 4      Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# ..                       ...                        ...
# 411  Francesc Maspons Labrós             Lo Rondallayre
# 412         Fernán Caballero                        NaN
# 413    Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 414    Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
# 415    Jacob & Wilhelm Grimm    Kinder- und Hausmärchen
#
#      Translated_from.Publication Date Translated_from.Language   ATU Language  \
# 0                              1812.0                   German   613  English
# 1                              1812.0                   German   441  English
# 2                              1812.0                   German   441  English
# 3                              1812.0                   German   450  English
# 4                              1812.0                   German   592  English
# ..                                ...                      ...   ...      ...
# 411                            1871.0                  Catalan  2023  English
# 412                               NaN                  Spanish   780  English
# 413                            1812.0                   German   222  English
# 414                            1812.0                   German   285  English
# 415                            1812.0                   German  672B  English
#
#       Origin                      Author  \
# 0    Germany                         NaN
# 1    Germany               Margaret Hunt
# 2    Germany                         NaN
# 3    Germany                         NaN
# 4    Germany                         NaN
# ..       ...                         ...
# 411    Spain  Jason F. Quackenbush, Esq.
# 412    Spain              Amanda Cibulka
# 413  Germany     Jacob and Wilhelm Grimm
# 414  Germany                         NaN
# 415  Germany                         NaN
#
#                                             Book Title  Publication Date  \
# 0                                                  NaN               NaN
# 1                              Grimm's Household Tales            1884.0
# 2                              Grimm's Household Tales            1884.0
# 3                                                  NaN               NaN
# 4                              Grimm's Household Tales            1884.0
# ..                                                 ...               ...
# 411                                               ibid            2016.0
# 412                                               ibid            2017.0
# 413  Jacob and Wilhelm Grimm. Household Tales. The ...            1909.0
# 414                            Grimm's Household Tales            1884.0
# 415                            Grimm's Household Tales            1884.0
#
#                                          clean_stories  \
# 0     hill and vale  not come together  but the chi...
# 1     there was once  countryman who had money and ...
# 2     there was once  mother who had  little boy  s...
# 3    and the sister wept over her poor lost brother...
# 4     there was once  rich man  who had  servant wh...
# ..                                                 ...
# 411   once upon  time   purdy little mouse sat  her...
# 412    valencian version   long  long ago  there wa...
# 413   once  summer time the bear and the wolf were ...
# 414   there was once  little child whose mother gav...
# 415   there was once  little child whose mother gav...
#
#                                             type1_data  \
# 0    {'tailor': 0.6712439515140128, 'shoemaker': 0....
# 1    {'hedgehog': 0.6759177518728824, 'han': 0.5139...
# 2    {'shroud': 0.4750570897663063, 'mother': 0.385...
# 3    {'fawn': 0.8002964731612497, 'soft': 0.1514392...
# 4    {'jew': 0.6036372132762582, 'servant': 0.32042...
# ..                                                 ...
# 411  {'mouse': 0.4389333527500325, 'bouquet': 0.384...
# 412  {'flute': 0.5424355628457117, 'shepherd': 0.36...
# 413  {'wren': 0.5071454109815293, 'bear': 0.3202121...
# 414  {'snake': 0.714902966541677, 'huhu': 0.3128483...
# 415  {'snake': 0.714902966541677, 'huhu': 0.3128483...
#
#                                             type2_data
# 0    {'tailor': 0.6934414559899187, 'shoemaker': 0....
# 1    {'hedgehog': 0.6960061818523211, 'hans': 0.511...
# 2    {'shroud': 0.4644993586035836, 'mother': 0.376...
# 3    {'fawn': 0.7942240142108445, 'soft': 0.1502901...
# 4    {'jew': 0.5929197604136036, 'servant': 0.37508...
# ..                                                 ...
# 411  {'mouse': 0.44735722402775197, 'bouquet': 0.37...
# 412  {'flute': 0.5378709338430943, 'shepherd': 0.36...
# 413  {'wren': 0.35089988495709845, 'bear': 0.338819...
# 414  {'snake': 0.7325109665096652, 'huhu': 0.298681...
# 415  {'snake': 0.7325109665096652, 'huhu': 0.298681...
#
# [416 rows x 16 columns]
